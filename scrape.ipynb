# %%
import os
import re

from bs4 import BeautifulSoup
import pandas as pd
import requests

from util import load_json_in, to_json_in, map_dict_value, flatten

# %% [markdown]
# # References

# %% [markdown]
# - [re — Regular expression operations](https://docs.python.org/3/library/re.html)
# - [Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)

# %% [markdown]
# # Specializations

# %% [markdown]
# Data Format:
# ```{json}
# {
#     "Computational Perception and Robotics": {
#         "Core Courses": [
#             {
#                 "Pick": 1,
#                 "Courses: [...]
#             },
#             {
#                 "Pick": 1,
#                 "Courses: [...]
#             }
#         ],
#         "Electives": [
#             {
#                 "Pick", 3,
#                 "Courses": [...]
#             }
#         ]
#     }
# }
#
# ```
#
# Limitations:
# - No information about constraints like "at least one from each sub-area" in Computational Perception and Robotics and Human-Computer Interaction
# - No information about "OR" constraints in Computing Systems and Human-Computer Interaction

# %%
response = requests.get('https://www.cc.gatech.edu/ms-computer-science-specializations')
soup = BeautifulSoup(response.text)
div = soup.find('div', class_='gt-main-content').find('div', class_='field')

# %%
core_electives = re.compile('Core Courses|Electives', re.I)
pick_take = re.compile('Pick|Take', re.I)
num = re.compile('one|two|three', re.I)
word_to_num = {
    'one': 1,
    'two': 2,
    'three': 3,
}
PICK = 'Pick'
COURSES = 'Courses'

tracks = {}
track = {}
course_subset = []

for child in div.children:
    text = child.text.strip()
    # A new track
    if child.name == 'h4':
        track = {}
        tracks[text] = track
    elif child.name == 'p':
        # A new course type (core or elective)
        if match := re.match(core_electives, text):
            course_type = match[0].title()
            course_subset = []
            track[course_type] = course_subset
            # If the next or next next text do not contain "pick" or "take"
            next = child.next_sibling.next_sibling
            next_next = next.next_sibling.next_sibling
            if not re.search(pick_take, next.text) and not re.search(pick_take, next_next.text):
                courses = {PICK: -1, COURSES: []}
                course_subset.append(courses)
        # A new course subset
        elif match := re.search(pick_take, text):
            # Extract the number of courses need to pick from the subset
            number_in_word = re.search(num, text)[0].lower()
            pick = word_to_num[number_in_word]
            courses = {PICK: pick, COURSES: []}
            course_subset.append(courses)
        # Handle an edge case
        elif text.lower() == 'or':
            courses[PICK] = 1
        
    # Course List
    elif child.name == 'ul':
        lis = child.find_all('li')
        for li in child.find_all('li'):
            course = re.sub(r'\s+', ' ', li.text.strip())
            if ' OR ' in course:
                for c in course.split(' OR '):
                    courses[COURSES].append(c)
            else:
                courses[COURSES].append(course)
        # If it does not say take a certain number of courses, all need to be taken
        if courses[PICK] == -1:
            courses[PICK] = len(lis)

del tracks['Human Centered Computing']
del tracks['Interactive Intelligence']
to_json_in('data', 'tracks.json', tracks)

# %% [markdown]
# # Free Courses

# %%
response = requests.get('https://www.udacity.com/georgia-tech')
soup = BeautifulSoup(response.text)
lis = soup.find('ul', class_='courses').find_all('li')

# %%
free_course_to_link = {}
for li in lis:
    a = li.find_all('a')[1]
    href = a['href']
    free_course_to_link[a.text.strip()] = f'https://www.udacity.com/{href}'

# %% [markdown]
# # OMSCS Courses

# %%
response = requests.get('https://omscs.gatech.edu/current-courses')
soup = BeautifulSoup(response.text)
div = soup.find('div', class_='body')
lis = div.find_all('li')
as_ = [li.a for li in lis]

# %%
omscs_course_to_link = {}
for a in as_:
    course = re.sub(r'\s+', ' ', a.text.strip())
    course = re.sub(':', '', a.text.strip())
    omscs_course_to_link[course] = a['href']

# %%
len(omscs_course_to_link)
# Out:
# 61

# %% [markdown]
# # Data Analysis

# %%
PICK = 'Pick'
COURSES = 'Courses'

tracks = load_json_in('data', 'tracks.json')

# %%
track_to_type_courses = map_dict_value(tracks, map_dict_value, lambda v: flatten([e[COURSES] for e in v]))
track_to_courses = map_dict_value(tracks, lambda v: flatten([e[COURSES] for e in flatten(v.values())]))

# %%
courses = flatten(track_to_courses.values())

all_courses = list(set(courses))
all_courses = [course for course in all_courses if not re.search('Any|Substitutions', course)]

# %% [markdown]
# Does each track have two course types (core and elective)?

# %%
pd.DataFrame(map_dict_value(tracks, len), index=['Course Types']).T
# Out:
#                                        Course Types
# Computational Perception and Robotics             2
# Computer Graphics                                 2
# Computing Systems                                 2
# High Performance Computing                        2
# Human-Computer Interaction                        2
# Machine Learning                                  2
# Modeling and Simulations                          2
# Scientific Computing                              2
# Social Computing                                  2
# Visual Analytics                                  2

# %% [markdown]
# How many courses can you choose from for each track?

# %%
track_type_course_count = pd.merge(
    pd.DataFrame(map_dict_value(track_to_type_courses, map_dict_value, len)).T,
    pd.DataFrame(map_dict_value(track_to_courses, len), index=['Total']).T,
    left_index=True,
    right_index=True,
)
track_type_course_count.T.to_json(os.path.join('data', 'track_type_course_count.json'), indent=4)
track_type_course_count
# Out:
#                                        Core Courses  Electives  Total
# Computational Perception and Robotics             9         13     22
# Computer Graphics                                 5          8     13
# Computing Systems                                11         25     36
# High Performance Computing                        2          7      9
# Human-Computer Interaction                        3         19     22
# Machine Learning                                 10         22     32
# Modeling and Simulations                          4          7     11
# Scientific Computing                              3          8     11
# Social Computing                                  3         16     19
# Visual Analytics                                  3          8     11

# %% [markdown]
# How many unique courses in the whole program?

# %%
to_json_in('data', 'all_courses.json', sorted(all_courses))
len(all_courses)
# Out:
# 116

# %% [markdown]
# What the number of overlapping courses between tracks?

# %%
track_overlap_courses = {}
for track_a, courses_a in track_to_courses.items():
    track_overlap_courses[track_a] = {}
    for track_b, courses_b in track_to_courses.items():
        overlap_courses = list(set(courses_a) & set(courses_b)) if track_a != track_b else []
        track_overlap_courses[track_a][track_b] = sorted(overlap_courses)

to_json_in('data', 'track_overlap_courses.json', track_overlap_courses)
pd.DataFrame(map_dict_value(track_overlap_courses, map_dict_value, len))
# Out:
#                                        Computational Perception and Robotics  \
# Computational Perception and Robotics                                      0
# Computer Graphics                                                          4
# Computing Systems                                                          3
# High Performance Computing                                                 1
# Human-Computer Interaction                                                 0
# Machine Learning                                                          11
# Modeling and Simulations                                                   0
# Scientific Computing                                                       1
# Social Computing                                                           3
# Visual Analytics                                                           1
#
#                                        Computer Graphics  Computing Systems  \
# Computational Perception and Robotics                  4                  3
# Computer Graphics                                      0                  2
# Computing Systems                                      2                  0
# High Performance Computing                             0                  3
# Human-Computer Interaction                             2                  0
# Machine Learning                                       3                  4
# Modeling and Simulations                               0                  2
# Scientific Computing                                   0                  1
# Social Computing                                       3                  8
# Visual Analytics                                       1                  0
#
#                                        High Performance Computing  \
# Computational Perception and Robotics                           1
# Computer Graphics                                               0
# Computing Systems                                               3
# High Performance Computing                                      0
# Human-Computer Interaction                                      0
# Machine Learning                                                1
# Modeling and Simulations                                        2
# Scientific Computing                                            4
# Social Computing                                                0
# Visual Analytics                                                0
#
#                                        Human-Computer Interaction  \
# Computational Perception and Robotics                           0
# Computer Graphics                                               2
# Computing Systems                                               0
# High Performance Computing                                      0
# Human-Computer Interaction                                      0
# Machine Learning                                                0
# Modeling and Simulations                                        0
# Scientific Computing                                            0
# Social Computing                                                8
# Visual Analytics                                                7
#
#                                        Machine Learning  \
# Computational Perception and Robotics                11
# Computer Graphics                                     3
# Computing Systems                                     4
# High Performance Computing                            1
# Human-Computer Interaction                            0
# Machine Learning                                      0
# Modeling and Simulations                              1
# Scientific Computing                                  1
# Social Computing                                      4
# Visual Analytics                                      2
#
#                                        Modeling and Simulations  \
# Computational Perception and Robotics                         0
# Computer Graphics                                             0
# Computing Systems                                             2
# High Performance Computing                                    2
# Human-Computer Interaction                                    0
# Machine Learning                                              1
# Modeling and Simulations                                      0
# Scientific Computing                                          2
# Social Computing                                              1
# Visual Analytics                                              0
#
#                                        Scientific Computing  Social Computing  \
# Computational Perception and Robotics                     1                 3
# Computer Graphics                                         0                 3
# Computing Systems                                         1                 8
# High Performance Computing                                4                 0
# Human-Computer Interaction                                0                 8
# Machine Learning                                          1                 4
# Modeling and Simulations                                  2                 1
# Scientific Computing                                      0                 0
# Social Computing                                          0                 0
# Visual Analytics                                          0                 6
#
#                                        Visual Analytics
# Computational Perception and Robotics                 1
# Computer Graphics                                     1
# Computing Systems                                     0
# High Performance Computing                            0
# Human-Computer Interaction                            7
# Machine Learning                                      2
# Modeling and Simulations                              0
# Scientific Computing                                  0
# Social Computing                                      6
# Visual Analytics                                      0

# %%
course_to_free_course = {
    "CS 6200 Graduate Introduction to Operating Systems": "Introduction to Operating Systems",
    "CS 6300 Software Development Process": "Software Development Process",
    "CS 7642 Reinforcement Learning and Decision Making": "Reinforcement Learning",
    "CS 6250 Computer Networks": "Computer Networking",
    "CS 6515 Introduction to Graduate Algorithms": "Introduction to Graduate Algorithms",
    "CS 6505 Computability, Algorithms, and Complexity": "Computability, Complexity & Algorithms",
    "CS 6400 Database Systems Concepts and Designs": "Database Systems Concepts & Design",
    "CS 6460 Educational Technology: Conceptual Foundations": "Educational Technology",
    "CS 6750 Human-Computer Interaction": "Human-Computer Interaction",
    "CS 6476 Computer Vision": "Introduction to Computer Vision",
    "CSE 6220 High Performance Computing": "High Performance Computing",
    "CS 6601 Artificial Intelligence": "Artificial Intelligence",
    "CS 6210 Advanced Operating Systems": "Advanced Operating Systems",
    "CS 7638 Artificial Intelligence Techniques for Robotics": "Artificial Intelligence for Robotics",
    "CS 6310 Software Architecture and Design": "Software Architecture & Design",
    "CS 7641 Machine Learning": "Machine Learning",
    "CS 6475 Computational Photography": "Computational Photography",
    "CS 6262 Network Security": "Network Security",
    "CSE 6250 Big Data for Health": "Big Data Analytics in Healthcare",
    "CS 6290 High-Performance Computer Architecture": "High Performance Computer Architecture",
    "CS 6340 Software Analysis and Testing": "Software Analysis & Testing",
    "CS 7646 Machine Learning for Trading": "Machine Learning for Trading",
    "CS 6035 Introduction to Information Security": "Introduction to Information Security",
    "CSE 6242 Data and Visual Analytics": "Data Analysis and Visualization"
}
# to_json_in('data', 'course_to_free_course.json', course_to_free_course)

# %%
[
    'Knowledge-Based AI: Cognitive Systems',
    'Linear Algebra Refresher Course',
    'GT - Refresher - Advanced OS',
    'Compilers: Theory and Practice',
    'Embedded Systems',
    'Cyber-Physical Systems Security',
    'Machine Learning: Unsupervised Learning'
]
# Out:
# ['Knowledge-Based AI: Cognitive Systems',
#  'Linear Algebra Refresher Course',
#  'GT - Refresher - Advanced OS',
#  'Compilers: Theory and Practice',
#  'Embedded Systems',
#  'Cyber-Physical Systems Security',
#  'Machine Learning: Unsupervised Learning']

# %%
course_to_free_course_info = pd.merge(
    pd.Series(course_to_free_course, name='Free Course'),
    pd.Series(free_course_to_link, name='Free Course Link'),
    left_on='Free Course',
    right_index=True,
)
course_to_free_course_info
# Out:
#                                                                                Free Course  \
# CS 6200 Graduate Introduction to Operating Systems       Introduction to Operating Systems
# CS 6300 Software Development Process                          Software Development Process
# CS 7642 Reinforcement Learning and Decision Making                  Reinforcement Learning
# CS 6250 Computer Networks                                              Computer Networking
# CS 6515 Introduction to Graduate Algorithms            Introduction to Graduate Algorithms
# CS 6505 Computability, Algorithms, and Complexity   Computability, Complexity & Algorithms
# CS 6400 Database Systems Concepts and Designs           Database Systems Concepts & Design
# CS 6460 Educational Technology: Conceptual Foun...                  Educational Technology
# CS 6750 Human-Computer Interaction                              Human-Computer Interaction
# CS 6476 Computer Vision                                    Introduction to Computer Vision
# CSE 6220 High Performance Computing                             High Performance Computing
# CS 6601 Artificial Intelligence                                    Artificial Intelligence
# CS 6210 Advanced Operating Systems                              Advanced Operating Systems
# CS 7638 Artificial Intelligence Techniques for ...    Artificial Intelligence for Robotics
# CS 6310 Software Architecture and Design                    Software Architecture & Design
# CS 7641 Machine Learning                                                  Machine Learning
# CS 6475 Computational Photography                                Computational Photography
# CS 6262 Network Security                                                  Network Security
# CSE 6250 Big Data for Health                              Big Data Analytics in Healthcare
# CS 6290 High-Performance Computer Architecture      High Performance Computer Architecture
# CS 6340 Software Analysis and Testing                          Software Analysis & Testing
# CS 7646 Machine Learning for Trading                          Machine Learning for Trading
# CS 6035 Introduction to Information Security          Introduction to Information Security
# CSE 6242 Data and Visual Analytics                         Data Analysis and Visualization
#
#                                                                                      Free Course Link
# CS 6200 Graduate Introduction to Operating Systems  https://www.udacity.com/course/introduction-to...
# CS 6300 Software Development Process                https://www.udacity.com/course/software-develo...
# CS 7642 Reinforcement Learning and Decision Making  https://www.udacity.com/course/reinforcement-l...
# CS 6250 Computer Networks                           https://www.udacity.com/course/computer-networ...
# CS 6515 Introduction to Graduate Algorithms         https://www.udacity.com/course/introduction-to...
# CS 6505 Computability, Algorithms, and Complexity   https://www.udacity.com/course/computability-c...
# CS 6400 Database Systems Concepts and Designs       https://www.udacity.com/course/database-system...
# CS 6460 Educational Technology: Conceptual Foun...  https://www.udacity.com/course/educational-tec...
# CS 6750 Human-Computer Interaction                  https://www.udacity.com/course/human-computer-...
# CS 6476 Computer Vision                             https://www.udacity.com/course/introduction-to...
# CSE 6220 High Performance Computing                 https://www.udacity.com/course/high-performanc...
# CS 6601 Artificial Intelligence                     https://www.udacity.com/course/artificial-inte...
# CS 6210 Advanced Operating Systems                  https://www.udacity.com/course/advanced-operat...
# CS 7638 Artificial Intelligence Techniques for ...  https://www.udacity.com/course/artificial-inte...
# CS 6310 Software Architecture and Design            https://www.udacity.com/course/software-archit...
# CS 7641 Machine Learning                            https://www.udacity.com/course/machine-learnin...
# CS 6475 Computational Photography                   https://www.udacity.com/course/computational-p...
# CS 6262 Network Security                            https://www.udacity.com/course/network-securit...
# CSE 6250 Big Data for Health                        https://www.udacity.com/course/big-data-analyt...
# CS 6290 High-Performance Computer Architecture      https://www.udacity.com/course/high-performanc...
# CS 6340 Software Analysis and Testing               https://www.udacity.com/course/software-analys...
# CS 7646 Machine Learning for Trading                https://www.udacity.com/course/machine-learnin...
# CS 6035 Introduction to Information Security        https://www.udacity.com/course/intro-to-inform...
# CSE 6242 Data and Visual Analytics                  https://www.udacity.com/course/data-analysis-a...

# %%
all_course_df = pd.DataFrame(all_courses, columns=['Course'])
omscs_course_to_link_df = pd.DataFrame(omscs_course_to_link, index=['OMSCS Course Link']).T
omscs_course_to_link_df = omscs_course_to_link_df.reset_index(names='Course')

# %%
all_course_df['Course Code'] = all_course_df['Course'].apply(lambda e: ' '.join(e.split(' ')[:2]))
all_course_df
# Out:
#                                                 Course Course Code
# 0    CSE 8803 Special Topics: Algorithms for Medica...    CSE 8803
# 1        CS 6400 Database Systems Concepts and Designs     CS 6400
# 2              CS 7470 Mobile and Ubiquitous Computing     CS 7470
# 3                    CS 6475 Computational Photography     CS 6475
# 4                             CS 7650 Natural Language     CS 7650
# ..                                                 ...         ...
# 111                  ISYE 6664 Stochastic Optimization   ISYE 6664
# 112  CS 6460 Educational Technology: Conceptual Fou...     CS 6460
# 113             CS 6422 Database System Implementation     CS 6422
# 114  CSE 6730 Modeling and Simulation: Foundations ...    CSE 6730
# 115                   CS 7535 Markov Chain Monte Carlo     CS 7535
#
# [116 rows x 2 columns]

# %%
omscs_course_to_link_df['Course Code'] = omscs_course_to_link_df['Course'].apply(lambda e: ' '.join(e.split(' ')[:2]))
omscs_course_to_link_df
# Out:
#                                                Course  \
# 0        CS 6035 Introduction to Information Security
# 1                          CS 6150 Computing for Good
# 2           CS 6200 Introduction to Operating Systems
# 3                  CS 6210 Advanced Operating Systems
# 4           CS 6211 System Design for Cloud Computing
# ..                                                ...
# 56  ISYE 6644 Simulation and Modeling for Engineer...
# 57               ISYE 6669 Deterministic Optimization
# 58  ISYE 8803 Topics on High-Dimensional Data Anal...
# 59                         MGT 6311 Digital Marketing
# 60            PUBP 6725 Information Security Policies
#
#                                     OMSCS Course Link Course Code
# 0   https://omscs.gatech.edu/cs-6035-introduction-...     CS 6035
# 1     https://omscs.gatech.edu/cs-6150-computing-good     CS 6150
# 2   https://omscs.gatech.edu/cs-6200-introduction-...     CS 6200
# 3   https://omscs.gatech.edu/cs-6210-advanced-oper...     CS 6210
# 4   https://omscs.gatech.edu/cs-6211-system-design...     CS 6211
# ..                                                ...         ...
# 56  https://omscs.gatech.edu/isye-6644-simulation-...   ISYE 6644
# 57  https://omscs.gatech.edu/isye-6669-determinist...   ISYE 6669
# 58  https://omscs.gatech.edu/isye-8803-topics-high...   ISYE 8803
# 59  https://omscs.gatech.edu/mgt-6311-digital-mark...    MGT 6311
# 60  https://omscs.gatech.edu/pubp-6725-information...   PUBP 6725
#
# [61 rows x 3 columns]

# %%
course_to_link = pd.merge(
    all_course_df,
    omscs_course_to_link_df,
    left_on='Course Code',
    right_on='Course Code',
    how='left',
    suffixes=('', ' OMSCS')
)
course_to_link = course_to_link.query('`Course Code` != "CS 8803"')
course_to_link = course_to_link.set_index('Course').rename(columns={'Course OMSCS': 'OMSCS Course'})
course_to_link
# Out:
#                                                    Course Code  \
# Course
# CSE 8803 Special Topics: Algorithms for Medical...    CSE 8803
# CS 6400 Database Systems Concepts and Designs          CS 6400
# CS 7470 Mobile and Ubiquitous Computing                CS 7470
# CS 6475 Computational Photography                      CS 6475
# CS 7650 Natural Language                               CS 7650
# ...                                                        ...
# ISYE 6664 Stochastic Optimization                    ISYE 6664
# CS 6460 Educational Technology: Conceptual Foun...     CS 6460
# CS 6422 Database System Implementation                 CS 6422
# CSE 6730 Modeling and Simulation: Foundations a...    CSE 6730
# CS 7535 Markov Chain Monte Carlo                       CS 7535
#
#                                                                                     OMSCS Course  \
# Course
# CSE 8803 Special Topics: Algorithms for Medical...                                           NaN
# CS 6400 Database Systems Concepts and Designs       CS 6400 Database Systems Concepts and Design
# CS 7470 Mobile and Ubiquitous Computing                    CS 7470 Mobile & Ubiquitous Computing
# CS 6475 Computational Photography                              CS 6475 Computational Photography
# CS 7650 Natural Language                                     CS 7650 Natural Language Processing
# ...                                                                                          ...
# ISYE 6664 Stochastic Optimization                                                            NaN
# CS 6460 Educational Technology: Conceptual Foun...                CS 6460 Educational Technology
# CS 6422 Database System Implementation                                                       NaN
# CSE 6730 Modeling and Simulation: Foundations a...                                           NaN
# CS 7535 Markov Chain Monte Carlo                                                             NaN
#
#                                                                                     OMSCS Course Link
# Course
# CSE 8803 Special Topics: Algorithms for Medical...                                                NaN
# CS 6400 Database Systems Concepts and Designs       https://omscs.gatech.edu/cs-6400-database-syst...
# CS 7470 Mobile and Ubiquitous Computing             https://omscs.gatech.edu/cs-7470-mobile-ubiqui...
# CS 6475 Computational Photography                   https://omscs.gatech.edu/cs-6475-computational...
# CS 7650 Natural Language                            https://omscs.gatech.edu/cs-7650-natural-langu...
# ...                                                                                               ...
# ISYE 6664 Stochastic Optimization                                                                 NaN
# CS 6460 Educational Technology: Conceptual Foun...  https://omscs.gatech.edu/cs-6460-educational-t...
# CS 6422 Database System Implementation                                                            NaN
# CSE 6730 Modeling and Simulation: Foundations a...                                                NaN
# CS 7535 Markov Chain Monte Carlo                                                                  NaN
#
# [114 rows x 3 columns]

# %%
course_to_link['OMSCS Course'].value_counts()
# Out:
# OMSCS Course
# CS 6457 Video Game Design                                        2
# CS 6400 Database Systems Concepts and Design                     1
# CS 6675 Advanced Internet Systems and Applications               1
# CS 6300 Software Development Process                             1
# CS 6440 Intro to Health Informatics                              1
# CS 6476 Computer Vision                                          1
# CS 7638 Robotics AI Techniques                                   1
# CS 7210 Distributed Computing                                    1
# CS 6603 AI, Ethics, and Society                                  1
# CS 6250 Computer Networks                                        1
# CS 6262 Network Security                                         1
# CS 6260 Applied Cryptography                                     1
# CS 6515 Intro to Graduate Algorithms                             1
# CS 7646 Machine Learning for Trading                             1
# CS 6263 Intro to Cyber Physical Systems Security                 1
# CS 6200 Introduction to Operating Systems                        1
# CS 6238 Secure Computer Systems                                  1
# CS 7641 Machine Learning                                         1
# CSE 6242 Data and Visual Analytics                               1
# CS 6310 Software Architecture and Design                         1
# CS 7470 Mobile & Ubiquitous Computing                            1
# ISYE 6420 Bayesian Statistics                                    1
# CS 6475 Computational Photography                                1
# CS 7650 Natural Language Processing                              1
# CSE 6250 Big Data for Health Informatics                         1
# CS 6750 Human-Computer Interaction                               1
# CS 6601 Artificial Intelligence                                  1
# CS 6290 High Performance Computer Architecture                   1
# CS 6035 Introduction to Information Security                     1
# CS 7642 Reinforcement Learning                                   1
# CSE 6220 Intro to High-Performance Computing                     1
# CS 6340 Software Analysis                                        1
# CS 6291 Embedded Systems Optimization                            1
# CS 7280 Network Science                                          1
# ISYE 6644 Simulation and Modeling for Engineering and Science    1
# CS 7643 Deep Learning                                            1
# CS 6210 Advanced Operating Systems                               1
# CS 7639 Cyber-Physical Design and Analysis                       1
# CS 6460 Educational Technology                                   1
# Name: count, dtype: int64

# %%
course_to_link.query('`Course Code` == "CS 6457"')
# Out:
#                                           Course Code  \
# Course
# CS 6457 Video Game Design and Programming     CS 6457
# CS 6457 Video Game Design                     CS 6457
#
#                                                         OMSCS Course  \
# Course
# CS 6457 Video Game Design and Programming  CS 6457 Video Game Design
# CS 6457 Video Game Design                  CS 6457 Video Game Design
#
#                                                                            OMSCS Course Link
# Course
# CS 6457 Video Game Design and Programming  https://omscs.gatech.edu/cs-6457-video-game-de...
# CS 6457 Video Game Design                  https://omscs.gatech.edu/cs-6457-video-game-de...

# %%
course_to_links = pd.merge(
    course_to_link,
    course_to_free_course_info,
    left_index=True,
    right_index=True,
    how='left',
)
course_to_links.T.to_json(os.path.join('data', 'course_to_links.json'), indent=4)
course_to_links
# Out:
#                                                    Course Code  \
# Course
# CSE 8803 Special Topics: Algorithms for Medical...    CSE 8803
# CS 6400 Database Systems Concepts and Designs          CS 6400
# CS 7470 Mobile and Ubiquitous Computing                CS 7470
# CS 6475 Computational Photography                      CS 6475
# CS 7650 Natural Language                               CS 7650
# ...                                                        ...
# ISYE 6664 Stochastic Optimization                    ISYE 6664
# CS 6460 Educational Technology: Conceptual Foun...     CS 6460
# CS 6422 Database System Implementation                 CS 6422
# CSE 6730 Modeling and Simulation: Foundations a...    CSE 6730
# CS 7535 Markov Chain Monte Carlo                       CS 7535
#
#                                                                                     OMSCS Course  \
# Course
# CSE 8803 Special Topics: Algorithms for Medical...                                           NaN
# CS 6400 Database Systems Concepts and Designs       CS 6400 Database Systems Concepts and Design
# CS 7470 Mobile and Ubiquitous Computing                    CS 7470 Mobile & Ubiquitous Computing
# CS 6475 Computational Photography                              CS 6475 Computational Photography
# CS 7650 Natural Language                                     CS 7650 Natural Language Processing
# ...                                                                                          ...
# ISYE 6664 Stochastic Optimization                                                            NaN
# CS 6460 Educational Technology: Conceptual Foun...                CS 6460 Educational Technology
# CS 6422 Database System Implementation                                                       NaN
# CSE 6730 Modeling and Simulation: Foundations a...                                           NaN
# CS 7535 Markov Chain Monte Carlo                                                             NaN
#
#                                                                                     OMSCS Course Link  \
# Course
# CSE 8803 Special Topics: Algorithms for Medical...                                                NaN
# CS 6400 Database Systems Concepts and Designs       https://omscs.gatech.edu/cs-6400-database-syst...
# CS 7470 Mobile and Ubiquitous Computing             https://omscs.gatech.edu/cs-7470-mobile-ubiqui...
# CS 6475 Computational Photography                   https://omscs.gatech.edu/cs-6475-computational...
# CS 7650 Natural Language                            https://omscs.gatech.edu/cs-7650-natural-langu...
# ...                                                                                               ...
# ISYE 6664 Stochastic Optimization                                                                 NaN
# CS 6460 Educational Technology: Conceptual Foun...  https://omscs.gatech.edu/cs-6460-educational-t...
# CS 6422 Database System Implementation                                                            NaN
# CSE 6730 Modeling and Simulation: Foundations a...                                                NaN
# CS 7535 Markov Chain Monte Carlo                                                                  NaN
#
#                                                                            Free Course  \
# Course
# CSE 8803 Special Topics: Algorithms for Medical...                                 NaN
# CS 6400 Database Systems Concepts and Designs       Database Systems Concepts & Design
# CS 7470 Mobile and Ubiquitous Computing                                            NaN
# CS 6475 Computational Photography                            Computational Photography
# CS 7650 Natural Language                                                           NaN
# ...                                                                                ...
# ISYE 6664 Stochastic Optimization                                                  NaN
# CS 6460 Educational Technology: Conceptual Foun...              Educational Technology
# CS 6422 Database System Implementation                                             NaN
# CSE 6730 Modeling and Simulation: Foundations a...                                 NaN
# CS 7535 Markov Chain Monte Carlo                                                   NaN
#
#                                                                                      Free Course Link
# Course
# CSE 8803 Special Topics: Algorithms for Medical...                                                NaN
# CS 6400 Database Systems Concepts and Designs       https://www.udacity.com/course/database-system...
# CS 7470 Mobile and Ubiquitous Computing                                                           NaN
# CS 6475 Computational Photography                   https://www.udacity.com/course/computational-p...
# CS 7650 Natural Language                                                                          NaN
# ...                                                                                               ...
# ISYE 6664 Stochastic Optimization                                                                 NaN
# CS 6460 Educational Technology: Conceptual Foun...  https://www.udacity.com/course/educational-tec...
# CS 6422 Database System Implementation                                                            NaN
# CSE 6730 Modeling and Simulation: Foundations a...                                                NaN
# CS 7535 Markov Chain Monte Carlo                                                                  NaN
#
# [114 rows x 5 columns]

# %%
set(course_to_free_course) - set(course_to_links.dropna().index)
# Out:
# {'CS 6505 Computability, Algorithms, and Complexity'}

# %%
len(course_to_links.dropna(subset=['OMSCS Course Link']))
# Out:
# 40
